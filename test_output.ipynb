# %% [markdown]
# # Analysis Session
# *Generated by Assay System*

# %% [markdown]
# **User**: Show me a chart

# %% [markdown]
# **Assistant**: Here it is:

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3])
